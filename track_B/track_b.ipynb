# %%
from tools.GetPath import GetPath
from time import sleep



get_path = GetPath(
    pert="Cebpb", target="Brd8dc",
    required_score=400,
    add_nodes=20,
)
result = get_path.get_path()
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       2 from time import sleep
#       6 get_path = GetPath(
#       7     pert="Cebpb", target="Brd8dc",
#       8     required_score=400,
#       9     add_nodes=20,
#      10 )
# ---> 11 result = get_path.get_path()
#      12 print(result)
#
# File ~/Desktop/JOB/Kaggle/BioReasoningChallenge/track_B/tools/GetPath.py:131, in GetPath.get_path(self)
#     123 if self.pert not in mapping or self.target not in mapping:
#     124     print({
#     125         "pert": self.pert,
#     126         "target": self.target,
#     127         "status": "mapping_failed",
#     128         "evidence": "STRING mapping failed for one or both genes."
#     129     })
# --> 131 edges = self.get_network_interactions(
#     132     [mapping[self.pert], mapping[self.target]],
#     133     species=self.SPECIES,
# ...
